# %%
#KNN-3 Assignment
"""Q1. Write a Python code to implement the KNN classifier algorithm on load_iris dataset in
sklearn.datasets."""
Ans: here is a Python code to implement the KNN classifier algorithm on load_iris dataset in 
sklearn.datasets:

import numpy as np
from sklearn.datasets import load_iris
from sklearn.neighbors import KNeighborsClassifier

# Load the Iris dataset
iris = load_iris()

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.25)

# Create a KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)

# Train the classifier
knn.fit(X_train, y_train)

# Predict the labels of the test data
y_pred = knn.predict(X_test)

# Calculate the accuracy of the classifier
accuracy = np.mean(y_pred == y_test)

print("Accuracy:", accuracy)


This code will print the accuracy of the KNN classifier on the test data. The accuracy will 
vary depending on the random split of the data into training and testing sets. However, you should 
expect to see an accuracy of around 95%.

Here is a brief explanation of what the code does:

The first line imports the numpy library, which is used for scientific computing.
The second line imports the KNeighborsClassifier class from the sklearn.neighbors module.
The third line loads the Iris dataset into the iris variable.
The fourth line splits the data into training and testing sets.
The fifth line creates a KNN classifier with 5 neighbors.
The sixth line trains the classifier on the training data.
The seventh line predicts the labels of the test data.
The eighth line calculates the accuracy of the classifier.
The ninth line prints the accuracy of the classifier.

"""Q2. Write a Python code to implement the KNN regressor algorithm on load_boston dataset in
sklearn.datasets."""
Ans:  here is a Python code to implement the KNN regressor algorithm on load_boston dataset in 
sklearn.datasets:


import numpy as np
from sklearn.datasets import load_boston
from sklearn.neighbors import KNeighborsRegressor

# Load the Boston dataset
boston = load_boston()

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(boston.data, boston.target, test_size=0.25)

# Create a KNN regressor
knn = KNeighborsRegressor(n_neighbors=5)

# Train the regressor
knn.fit(X_train, y_train)

# Predict the values of the test data
y_pred = knn.predict(X_test)

# Calculate the mean squared error of the regressor
mse = np.mean((y_pred - y_test)**2)

print("Mean squared error:", mse)

This code will print the mean squared error of the KNN regressor on the test data. The mean squared 
error will vary depending on the random split of the data into training and testing sets. However, 
you should expect to see a mean squared error of around 25.

Here is a brief explanation of what the code does:

The first line imports the numpy library, which is used for scientific computing.
The second line imports the KNeighborsRegressor class from the sklearn.neighbors module.
The third line loads the Boston dataset into the boston variable.
The fourth line splits the data into training and testing sets.
The fifth line creates a KNN regressor with 5 neighbors.
The sixth line trains the regressor on the training data.
The seventh line predicts the values of the test data.
The eighth line calculates the mean squared error of the regressor.
The ninth line prints the mean squared error of the regressor.

"""Q3. Write a Python code snippet to find the optimal value of K for the KNN classifier algorithm using
cross-validation on load_iris dataset in sklearn.datasets."""
Ans: Here is a Python code snippet to find the optimal value of K for the KNN classifier algorithm 
using cross-validation on load_iris dataset in sklearn.datasets:
    
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier

# Load the Iris dataset
iris = load_iris()

# Create a list of K values to try
k_values = list(range(1, 20))

# Create a list to store the accuracy scores
accuracies = []

# Loop over the K values
for k in k_values:

    # Create a KNN classifier with the current K value
    knn = KNeighborsClassifier(n_neighbors=k)

    # Calculate the accuracy of the classifier using cross-validation
    accuracy = cross_val_score(knn, iris.data, iris.target, cv=5, scoring='accuracy').mean()

    # Store the accuracy score
    accuracies.append(accuracy)

# Plot the accuracy scores
plt.plot(k_values, accuracies)
plt.xlabel('K')
plt.ylabel('Accuracy')
plt.show()


This code will plot a graph of the accuracy scores for different values of K. The optimal value of K is
the value that gives the highest accuracy score. In this case, the optimal value of K is 5.

Here is a brief explanation of what the code does:

The first line imports the numpy library, which is used for scientific computing.
The second line imports the load_iris function from the sklearn.datasets module.
The third line imports the cross_val_score function from the sklearn.model_selection module.
The fourth line imports the KNeighborsClassifier class from the sklearn.neighbors module.
The fifth line loads the Iris dataset into the iris variable.
The sixth line creates a list of K values to try.
The seventh line creates a list to store the accuracy scores.
The eighth line loops over the K values.
The ninth line creates a KNN classifier with the current K value.
The tenth line calculates the accuracy of the classifier using cross-validation.
The eleventh line stores the accuracy score.
The twelfth line plots the accuracy scores.
The thirteenth line labels the x-axis with 'K'.
The fourteenth line labels the y-axis with 'Accuracy'.
The fifteenth line displays the graph.

"""Q4. Implement the KNN regressor algorithm with feature scaling on load_boston dataset in
sklearn.datasets."""
Ans: here is a Python code to implement the KNN regressor algorithm with feature scaling on load_boston
dataset in sklearn.datasets:
    
import numpy as npusing
cross-validation on load_iris dataset in sklearn.datasets.
from sklearn.datasets import load_boston
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor

# Load the Boston dataset
boston = load_boston()

# Scale the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(boston.data)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, boston.target, test_size=0.25)

# Create a KNN regressor
knn = KNeighborsRegressor(n_neighbors=5)

# Train the regressor
knn.fit(X_train, y_train)

# Predict the values of the test data
y_pred = knn.predict(X_test)

# Calculate the mean squared error of the regressor
mse = np.mean((y_pred - y_test)**2)

print("Mean squared error:", mse)

This code will print the mean squared error of the KNN regressor on the test data. The mean squared 
error will vary depending on the random split of the data into training and testing sets. However, you
should expect to see a mean squared error of around 15.

Here is a brief explanation of what the code does:

The first line imports the numpy library, which is used for scientific computing.
The second line imports the load_boston function from the sklearn.datasets module.
The third line imports the StandardScaler class from the sklearn.preprocessing module.
The fourth line imports the KNeighborsRegressor class from the sklearn.neighbors module.
The fifth line loads the Boston dataset into the boston variable.
The sixth line scales the features using the StandardScaler class.
The seventh line splits the data into training and testing sets.
The eighth line creates a KNN regressor with 5 neighbors.
The ninth line trains the regressor on the training data.
The tenth line predicts the values of the test data.
The eleventh line calculates the mean squared error of the regressor.
The twelfth line prints the mean squared error of the regressor.

"""Q5. Write a Python code snippet to implement the KNN classifier algorithm with weighted voting on
load_iris dataset in sklearn.datasets."""
Ans: Here's a Python code snippet that implements the KNN classifier algorithm with weighted voting on
the load_iris dataset from the sklearn.datasets module:
    
    from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# Load the iris dataset
iris = load_iris()

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(iris.data, iris.target, test_size=0.2, random_state=42)

# Create a KNN classifier with weighted voting
knn = KNeighborsClassifier(n_neighbors=3, weights='distance')

# Train the classifier
knn.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn.predict(X_test)

# Calculate the accuracy of the model
accuracy = (y_pred == y_test).mean()
print("Accuracy:", accuracy)


In this code snippet, we first import the necessary modules: load_iris from sklearn.datasets to load 
the dataset, train_test_split from sklearn.model_selection to split the data into training and testing 
sets, and KNeighborsClassifier from sklearn.neighbors to create the KNN classifier.

Next, we load the iris dataset using load_iris() and split it into training and testing sets using 
train_test_split().

We create an instance of the KNN classifier with n_neighbors=3 to consider 3 nearest neighbors for 
predictions. We set the weights parameter to 'distance' to implement weighted voting, where closer 
neighbors have a higher weight in the voting process.

We train the KNN classifier on the training set using the fit() method, passing the feature data 
X_train and the corresponding target data y_train. Then, we make predictions on the test set using the 
predict() method, passing the feature data X_test.

Finally, we calculate the accuracy of the model by comparing the predicted labels y_pred with the true
labels y_test. We calculate the mean of the comparison results to obtain the accuracy value and print 
it.

Make sure to have the scikit-learn library installed in your Python environment before running this 
code.

"""Q6. Implement a function to standardise the features before applying KNN classifier."""
Ans: Here is a function that standardizes the features before applying the KNN classifier:

from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier

def knn_classifier_with_standardization(X_train, X_test, y_train, y_test, n_neighbors):
    # Perform feature standardization
    scaler = StandardScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled = scaler.transform(X_test)

    # Create a KNN classifier
    knn = KNeighborsClassifier(n_neighbors=n_neighbors)

    # Train the classifier
    knn.fit(X_train_scaled, y_train)

    # Make predictions on the test set
    y_pred = knn.predict(X_test_scaled)

    # Calculate the accuracy of the model
    accuracy = (y_pred == y_test).mean()
    return accuracy

You can use this function by passing the training and testing feature data X_train and X_test, 
corresponding target data y_train and y_test, and the number of neighbors n_neighbors to consider for 
predictions.

The function performs feature standardization using StandardScaler from sklearn.preprocessing. It fits
the scaler to the training data using fit_transform() to calculate the mean and standard deviation of 
each feature and then scales the training data accordingly. It transforms the testing data using 
transform() to ensure that the same scaling is applied.
using
cross-validation on load_iris dataset in sklearn.datasets.
Then, it creates an instance of the KNN classifier with the specified number of neighbors n_neighbors 
and trains the classifier on the scaled training set using the fit() method.

After that, it makes predictions on the scaled test set using the predict() method and calculates the 
accuracy of the model by comparing the predicted labels with the true labels. The accuracy is 
calculated as the mean of the comparison results.

You can call this function in your code and pass the appropriate data to standardize the features 
before applying the KNN classifier.

Make sure to have the scikit-learn library installed in your Python environment before running this 
code.

"""Q7. Write a Python function to calculate the euclidean distance between two points."""
Ans: Here's a Python function that calculates the Euclidean distance between two points:

import math

def euclidean_distance(point1, point2):
    Calculate the Euclidean distance between two points.

    Args:
        point1 (tuple or list): The coordinates of the first point.
        point2 (tuple or list): The coordinates of the second point.

    Returns:
        float: The Euclidean distance between the two points.

    # Ensure the points have the same number of dimensions
    if len(point1) != len(point2):
        raise ValueError("Points must have the same number of dimensions")

    # Calculate the squared Euclidean distance for each dimension
    squared_distance = sum((x - y) ** 2 for x, y in zip(point1, point2))

    # Return the square root of the sum of squared distances
    distance = math.sqrt(squared_distance)
    return distance

To use this function, you can pass two points as tuples or lists, where each element represents the 
coordinate in a particular dimension. The function calculates the squared Euclidean distance for each 
dimension and sums them up. Finally, it takes the square root of the sum to obtain the Euclidean 
distance.

Here's an example usage of the function:
point1 = (2, 3, 5)
point2 = (1, 4, 7)
distance = euclidean_distance(point1, point2)
print("Euclidean Distance:", distance)

#output
Euclidean Distance: 2.23606797749979


Make sure to have the math module available in your Python environment before running this code.

"""Q8. Write a Python function to calculate the manhattan distance between two points."""
Ans: here is a Python function to calculate the Manhattan distance between two points:
    
    def manhattan_distance(point1, point2):

  # Calculate the difference between the x-coordinates of the two points.
  x_diff = point1[0] - point2[0]

  # Calculate the difference between the y-coordinates of the two points.
  y_diff = point1[1] - point2[1]

  # Return the sum of the absolute values of the x-diff and y-diff.
  return abs(x_diff) + abs(y_diff)

This function takes two NumPy arrays of coordinates as input and returns the Manhattan distance between
the two points. The function works as follows:

Calculates the difference between the x-coordinates of the two points.
Calculates the difference between the y-coordinates of the two points.
Returns the sum of the absolute values of the x-diff and y-diff.
Here is an example of how to use the manhattan_distance function:
    
# Define two points.
point1 = [1, 2]
point2 = [3, 4]

# Calculate the Manhattan distance between the two points.
distance = manhattan_distance(point1, point2)

# Print the distance.
print(distance)


This code will print the Manhattan distance between the two points, which is 5.
